# %% [markdown]
# # Cleaning Data

# %%
# importing packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
# reading the raw data csv, dropped one data point 
dino_rawr_data = pd.read_csv('DinoData/data.csv').drop(['taxonomy', 'named_by'], axis = 1)
dino_rawr_data
# Out:
#                  name         diet  \
# 0            aardonyx  herbivorous
# 1         abelisaurus  carnivorous
# 2       achelousaurus  herbivorous
# 3        achillobator  carnivorous
# 4    acrocanthosaurus  carnivorous
# ..                ...          ...
# 304     yuanmousaurus  herbivorous
# 305     yunnanosaurus   omnivorous
# 306          zalmoxes  herbivorous
# 307     zephyrosaurus  herbivorous
# 308      zuniceratops  herbivorous
#
#                                          period      lived_in            type  \
# 0      Early Jurassic 199-189 million years ago  South Africa        sauropod
# 1       Late Cretaceous 74-70 million years ago     Argentina  large theropod
# 2       Late Cretaceous 83-70 million years ago           USA     ceratopsian
# 3       Late Cretaceous 99-84 million years ago      Mongolia  large theropod
# 4    Early Cretaceous 115-105 million years ago           USA  large theropod
# ..                                          ...           ...             ...
# 304      Mid Jurassic 180-159 million years ago         China        sauropod
# 305    Early Jurassic 205-190 million years ago         China        sauropod
# 306        Late Cretaceous 69 million years ago       Romania    euornithopod
# 307  Early Cretaceous 120-110 million years ago           USA    euornithopod
# 308     Late Cretaceous 94-89 million years ago           USA     ceratopsian
#
#     length       species                                               link
# 0     8.0m      celestae  https://www.nhm.ac.uk/discover/dino-directory/...
# 1     9.0m   comahuensis  https://www.nhm.ac.uk/discover/dino-directory/...
# 2     6.0m       horneri  https://www.nhm.ac.uk/discover/dino-directory/...
# 3     5.0m     giganteus  https://www.nhm.ac.uk/discover/dino-directory/...
# 4    12.0m     atokensis  https://www.nhm.ac.uk/discover/dino-directory/...
# ..     ...           ...                                                ...
# 304  17.0m  jiangyiensis  https://www.nhm.ac.uk/discover/dino-directory/...
# 305   7.0m        huangi  https://www.nhm.ac.uk/discover/dino-directory/...
# 306   3.0m      robustus  https://www.nhm.ac.uk/discover/dino-directory/...
# 307   1.8m       schaffi  https://www.nhm.ac.uk/discover/dino-directory/...
# 308    NaN  christopheri  https://www.nhm.ac.uk/discover/dino-directory/...
#
# [309 rows x 8 columns]

# %%
# removing all rows with NaN values
nan_index = [125]
for i in range(dino_rawr_data.shape[0]):
    if str(dino_rawr_data.get('length')[i]) == 'nan':
        nan_index.append(i)
dino_data = dino_rawr_data.drop(nan_index).reset_index().drop(['index'], axis = 1)
dino_data
# Out:
#                  name         diet  \
# 0            aardonyx  herbivorous
# 1         abelisaurus  carnivorous
# 2       achelousaurus  herbivorous
# 3        achillobator  carnivorous
# 4    acrocanthosaurus  carnivorous
# ..                ...          ...
# 285           yinlong  herbivorous
# 286     yuanmousaurus  herbivorous
# 287     yunnanosaurus   omnivorous
# 288          zalmoxes  herbivorous
# 289     zephyrosaurus  herbivorous
#
#                                          period      lived_in            type  \
# 0      Early Jurassic 199-189 million years ago  South Africa        sauropod
# 1       Late Cretaceous 74-70 million years ago     Argentina  large theropod
# 2       Late Cretaceous 83-70 million years ago           USA     ceratopsian
# 3       Late Cretaceous 99-84 million years ago      Mongolia  large theropod
# 4    Early Cretaceous 115-105 million years ago           USA  large theropod
# ..                                          ...           ...             ...
# 285      Mid Jurassic 159-154 million years ago         China     ceratopsian
# 286      Mid Jurassic 180-159 million years ago         China        sauropod
# 287    Early Jurassic 205-190 million years ago         China        sauropod
# 288        Late Cretaceous 69 million years ago       Romania    euornithopod
# 289  Early Cretaceous 120-110 million years ago           USA    euornithopod
#
#     length       species                                               link
# 0     8.0m      celestae  https://www.nhm.ac.uk/discover/dino-directory/...
# 1     9.0m   comahuensis  https://www.nhm.ac.uk/discover/dino-directory/...
# 2     6.0m       horneri  https://www.nhm.ac.uk/discover/dino-directory/...
# 3     5.0m     giganteus  https://www.nhm.ac.uk/discover/dino-directory/...
# 4    12.0m     atokensis  https://www.nhm.ac.uk/discover/dino-directory/...
# ..     ...           ...                                                ...
# 285   1.2m        downsi  https://www.nhm.ac.uk/discover/dino-directory/...
# 286  17.0m  jiangyiensis  https://www.nhm.ac.uk/discover/dino-directory/...
# 287   7.0m        huangi  https://www.nhm.ac.uk/discover/dino-directory/...
# 288   3.0m      robustus  https://www.nhm.ac.uk/discover/dino-directory/...
# 289   1.8m       schaffi  https://www.nhm.ac.uk/discover/dino-directory/...
#
# [290 rows x 8 columns]

# %%
# splitting the col. periods by ' ', to separate the period name (str), and the estimated existance time (int).
dino_data_years_split = dino_data.get('period').str.split(' ')
dino_data_years_split[97]
# Out:
# ['Early', 'Cretaceous']

# %%
# initializing empty lists to be filled during the for-loop
dino_data_periods = [] # stores period name as str (eg. 'Early Cretaceous') in dino_data_periods
dino_data_years_str = [] # stores years as a str in the form ('a-b') in dino_data_years_str


for i in range(0, 290, 1):
    dino_data_periods.append(dino_data_years_split[i][0] + ' ' + dino_data_years_split[i][1])
    if len(dino_data_years_split[i]) >= 3:
        dino_data_years_str.append(dino_data_years_split[i][2])
    else:
        # for rows with only a period, and no specific time, p
        dino_data_years_str.append(0)
dino_data_years_str[97]
# Out:
# 0

# %%
# initializing empty lists to be filled during the for-loop
dino_data_start_year = [] # stores start year as int 
dino_data_end_year = [] # stores end year as int
dino_data_span = [] #stores start_year-end_year as int

for i in range(0,290,1):
    if dino_data_years_str[i] == 0:
        dino_data_start_year.append(0)
        dino_data_end_year.append(0)        
    else:
        years_split = dino_data_years_str[i].split('-')
        start_year = int(years_split[0])
        dino_data_start_year.append(start_year)
        if len(years_split) > 1:
            end_year = int(years_split[1])
            dino_data_end_year.append(end_year)        
        else:
            end_year = 0
            dino_data_end_year.append(0)
    dino_data_span.append(start_year-end_year)
        
type(dino_data_start_year)
# Out:
# list

# %%
# adding the columns start year, end year, existance span
# dropping columns 'taxonomy' and 'named_by'
dino_data_clean = dino_data.assign(start_year = dino_data_start_year, \
                                           end_year = dino_data_end_year, \
                                           period = dino_data_periods, \
                                           existance_span = dino_data_span)
# re-naming columns
dino_data_clean.rename(columns = {'start_year':'start year (mil. years ago)'}, inplace = True)
dino_data_clean.rename(columns = {'end_year':'end year (mil. years ago)'}, inplace = True)
dino_data_clean.rename(columns = {'lived_in':'lived in'}, inplace = True)
dino_data_clean.rename(columns = {'existance_span':'existance span (mil. years)'}, inplace = True)
dino_data_clean
# Out:
#                  name         diet            period      lived in  \
# 0            aardonyx  herbivorous    Early Jurassic  South Africa
# 1         abelisaurus  carnivorous   Late Cretaceous     Argentina
# 2       achelousaurus  herbivorous   Late Cretaceous           USA
# 3        achillobator  carnivorous   Late Cretaceous      Mongolia
# 4    acrocanthosaurus  carnivorous  Early Cretaceous           USA
# ..                ...          ...               ...           ...
# 285           yinlong  herbivorous      Mid Jurassic         China
# 286     yuanmousaurus  herbivorous      Mid Jurassic         China
# 287     yunnanosaurus   omnivorous    Early Jurassic         China
# 288          zalmoxes  herbivorous   Late Cretaceous       Romania
# 289     zephyrosaurus  herbivorous  Early Cretaceous           USA
#
#                type length       species  \
# 0          sauropod   8.0m      celestae
# 1    large theropod   9.0m   comahuensis
# 2       ceratopsian   6.0m       horneri
# 3    large theropod   5.0m     giganteus
# 4    large theropod  12.0m     atokensis
# ..              ...    ...           ...
# 285     ceratopsian   1.2m        downsi
# 286        sauropod  17.0m  jiangyiensis
# 287        sauropod   7.0m        huangi
# 288    euornithopod   3.0m      robustus
# 289    euornithopod   1.8m       schaffi
#
#                                                   link  \
# 0    https://www.nhm.ac.uk/discover/dino-directory/...
# 1    https://www.nhm.ac.uk/discover/dino-directory/...
# 2    https://www.nhm.ac.uk/discover/dino-directory/...
# 3    https://www.nhm.ac.uk/discover/dino-directory/...
# 4    https://www.nhm.ac.uk/discover/dino-directory/...
# ..                                                 ...
# 285  https://www.nhm.ac.uk/discover/dino-directory/...
# 286  https://www.nhm.ac.uk/discover/dino-directory/...
# 287  https://www.nhm.ac.uk/discover/dino-directory/...
# 288  https://www.nhm.ac.uk/discover/dino-directory/...
# 289  https://www.nhm.ac.uk/discover/dino-directory/...
#
#      start year (mil. years ago)  end year (mil. years ago)  \
# 0                            199                        189
# 1                             74                         70
# 2                             83                         70
# 3                             99                         84
# 4                            115                        105
# ..                           ...                        ...
# 285                          159                        154
# 286                          180                        159
# 287                          205                        190
# 288                           69                          0
# 289                          120                        110
#
#      existance span (mil. years)
# 0                             10
# 1                              4
# 2                             13
# 3                             15
# 4                             10
# ..                           ...
# 285                            5
# 286                           21
# 287                           15
# 288                           69
# 289                           10
#
# [290 rows x 11 columns]

# %%
# save cleaned dataframe as csv
dino_data.to_csv('dino_data_cleaned.csv')

# %% [markdown]
# # visualizing data

# %% [markdown]
# ## groupby different categories
# grouping dino_data by different columns to see how many data points are in each group
# we can use this to decide where we want to perform data analysis, as it would be pointless to analyze a group with only one single individual in it for trends

# %%
# prints the categories, and the number of unique counts in each group, so we can see here, 
# the different number of count when grouping different categories
print('species:', dino_data.groupby('species').count().get('index').unique())
print('types:', dino_data.groupby('type').count().get('index').unique())
print('period:', dino_data.groupby('period').count().get('index').unique())
print('diet:', dino_data.groupby('diet').count().get('index').unique())
print('lived in:', dino_data.groupby('lived in').count().get('index').unique())
print('existance span:', dino_data.groupby('existance span (mil. years)').count().get('index').unique())
